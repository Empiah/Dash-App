# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline

df = pd.read_csv('Data/results.csv')
df.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
len(df['home_team'].unique())
# Out:
# 241

# %%
len(df['away_team'].unique())
# Out:
# 242

# %%
len(np.unique(df[['home_team','away_team']].values))
# Out:
# 244

# %%
df['date'] = pd.to_datetime(df['date'])
df['year'] = df['date'].dt.year
df.head()
# Out:
#         date home_team away_team  home_score  away_score tournament     city  \
# 0 1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1 1873-03-08   England  Scotland           4           2   Friendly   London
# 2 1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3 1875-03-06   England  Scotland           2           2   Friendly   London
# 4 1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral  year
# 0  Scotland    False  1872
# 1   England    False  1873
# 2  Scotland    False  1874
# 3   England    False  1875
# 4  Scotland    False  1876

# %%
df['year'].unique()
# Out:
# array([1872, 1873, 1874, 1875, 1876, 1877, 1878, 1879, 1880, 1881, 1882,
#        1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893,
#        1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904,
#        1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915,
#        1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926,
#        1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937,
#        1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948,
#        1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959,
#        1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970,
#        1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981,
#        1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992,
#        1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
# ...

# %%
df = df[df['year'] > 1950]

# %%
df['year'].unique()
# Out:
# array([1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961,
#        1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972,
#        1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983,
#        1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994,
#        1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005,
#        2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016,
#        2017, 2018])

# %%
df.head()
# Out:
#            date   home_team    away_team  home_score  away_score  \
# 3144 1951-02-06      France   Yugoslavia           2           1
# 3145 1951-02-18       Spain  Switzerland           6           3
# 3146 1951-02-24    Zimbabwe       Zambia           2           1
# 3147 1951-02-25  Costa Rica    Nicaragua           8           1
# 3148 1951-02-27      Panama   Costa Rica           2           0
#
#              tournament         city            country  neutral  year
# 3144           Friendly        Paris             France    False  1951
# 3145           Friendly       Madrid              Spain    False  1951
# 3146           Friendly    Salisbury  Southern Rhodesia    False  1951
# 3147  CCCF Championship  Panama City             Panama     True  1951
# 3148  CCCF Championship  Panama City             Panama    False  1951

# %%
dff = pd.read_csv('https://gist.githubusercontent.com/chriddyp/cb5392c35661370d95f300086accea51/raw/8e0768211f6b747c0db42a9ce9a0937dafcbd8b2/indicators.csv')
dff.head()
# Out:
#    Unnamed: 0 Country Name                                     Indicator Name  \
# 0           0   Arab World                Agriculture, value added (% of GDP)
# 1           1   Arab World             CO2 emissions (metric tons per capita)
# 2           2   Arab World  Domestic credit provided by financial sector (...
# 3           3   Arab World        Electric power consumption (kWh per capita)
# 4           4   Arab World       Energy use (kg of oil equivalent per capita)
#
#    Year  Value
# 0  1952    NaN
# 1  1952    NaN
# 2  1952    NaN
# 3  1952    NaN
# 4  1952    NaN

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85536 entries, 0 to 85535
# Data columns (total 5 columns):
# Unnamed: 0        85536 non-null int64
# Country Name      85536 non-null object
# Indicator Name    85536 non-null object
# Year              85536 non-null int64
# Value             36616 non-null float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 3.3+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35805 entries, 3144 to 38948
# Data columns (total 10 columns):
# date          35805 non-null datetime64[ns]
# home_team     35805 non-null object
# away_team     35805 non-null object
# home_score    35805 non-null int64
# away_score    35805 non-null int64
# tournament    35805 non-null object
# city          35805 non-null object
# country       35805 non-null object
# neutral       35805 non-null bool
# year          35805 non-null int64
# dtypes: bool(1), datetime64[ns](1), int64(3), object(5)
# memory usage: 2.8+ MB

# %%
england = df[df['home_team'] == 'England']
print(england)
# Out:
#             date home_team         away_team  home_score  away_score  \
# 3158  1951-04-14   England          Scotland           2           3
# 3162  1951-05-09   England         Argentina           2           1
# 3170  1951-05-19   England          Portugal           5           2
# 3211  1951-10-03   England            France           2           2
# 3226  1951-11-14   England  Northern Ireland           2           0
# 3234  1951-11-28   England           Austria           2           2
# 3345  1952-11-12   England             Wales           5           2
# 3348  1952-11-26   England           Belgium           5           0
# 3412  1953-04-18   England          Scotland           2           2
# 3509  1953-11-11   England  Northern Ireland           3           1
# 3518  1953-11-25   England           Hungary           3           6
# 3604  1954-06-26   England           Uruguay           2           4
# 3661  1954-11-10   England             Wales           3           2
# ...
